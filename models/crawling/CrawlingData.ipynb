# %% [markdown]
# ### **Import Library**

# %%
import pandas as pd
from datetime import datetime
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5732\1524203933.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### **Install Node.js**

# %%
# Instal Node.js (karena tweet-harvest dibuat menggunakan Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'NODE_MAJOR' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# v18.17.1

# %% [markdown]
# ### **Twitter Auth Token**

# %%
twitter_auth_token = 'a686d09ae485e6faba5736ab7e8662c4f47f539c'

# %% [markdown]
# ### **Crawl Data**

# %%
filename = 'pemilu2024.csv'
search_keyword = 'pemilu 2024 (#pemilu2024) lang:id'
limit = 100

# !npx --yes tweet-harvest@2.2.8 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# up to date, audited 130 packages in 4s
#
# 29 packages are looking for funding
#   run `npm fund` for details
#
# 1 low severity vulnerability
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
#
# Opening twitter search page...
#
#
# Filling in keywords: pemilu 2024 (#pemilu2024) lang:id
#
#
# Got some tweets, saving to file...
# Your tweets saved to: d:\Kuliah 20\Tugas Akhir\aplikasi\models\crawling\tweets-data\pemilu2024.csv
# Total tweets saved: 15
#
# Got some tweets, saving to file...
# Your tweets saved to: d:\Kuliah 20\Tugas Akhir\aplikasi\models\crawling\tweets-data\pemilu2024.csv
# Total tweets saved: 31
# Scrolling more...
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: d:\Kuliah 20\Tugas Akhir\aplikasi\models\crawling\tweets-data\pemilu2024.csv
# Total tweets saved: 48
#
# Got some tweets, saving to file...
# Your tweets saved to: d:\Kuliah 20\Tugas Akhir\aplikasi\models\crawling\tweets-data\pemilu2024.csv
# Total tweets saved: 64
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: d:\Kuliah 20\Tugas Akhir\aplikasi\models\crawling\tweets-data\pemilu2024.csv
# Total tweets saved: 84
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: d:\Kuliah 20\Tugas Akhir\aplikasi\models\crawling\tweets-data\pemilu2024.csv
# Total tweets saved: 101
#
# --Taking a break, waiting for 10 seconds...
# Already got 101 tweets, done scrolling...

# %%
# menentukan jalur ke file CSV 
file_path = f"tweets-data/{filename}"

# Baca file csv
df = pd.read_csv(file_path, delimiter=";")

# Tampilkan DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Tue Feb 13 00:57:42 +0000 2024  1757207383942775238
# 1    Tue Feb 13 00:57:30 +0000 2024  1757207335699931148
# 2    Tue Feb 13 00:56:44 +0000 2024  1757207139926544757
# 3    Tue Feb 13 00:56:21 +0000 2024  1757207045554700466
# 4    Tue Feb 13 00:56:01 +0000 2024  1757206961714847749
# ..                              ...                  ...
# 96   Mon Feb 12 22:19:51 +0000 2024  1757167658611650942
# 97   Mon Feb 12 22:19:23 +0000 2024  1757167541380849746
# 98   Mon Feb 12 22:18:05 +0000 2024  1757167216523637094
# 99   Mon Feb 12 22:16:02 +0000 2024  1757166698787229735
# 100  Mon Feb 12 22:14:15 +0000 2024  1757166253121110485
#
#                                              full_text  quote_count  \
# 0    Telah beredar buletin digital yang memuat tuli...            0
# 1    Biasanya berangkat kerja selalu kena macet, Al...            0
# 2    Hindari Golput agar aspirasi dapat terwujud 😎 ...            0
# 3             Exit poll abal2. Lawak lawak #Pemilu2024            0
# 4    Pemasangan bilik suara #Pemilu2024 #PemiluDama...            0
# ..                                                 ...          ...
# 96   https://t.co/uNnYxyEv4s  Dirut PLN Pimpin Lang...            0
# 97   ZECKY ALATAS CALON ANGGOTA DPD RI 2024-2029 DA...            0
# 98   ZECKY ALATAS CALON ANGGOTA DPD RI 2024-2029 DA...            0
# 99   Ini Film Dirty Vote" (Full Movie) di YouTube, ...            0
# 100  Pemilih Ekspresif dan Demokrasi #Pemilu2024 #A...            0
#
#      reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0              0              0               0   in  1575410964530225152
# 1              0              0               0   in  1690120786051567617
# 2              0              0               0   in           2919642200
# 3              0              0               0   in            178600482
# 4              0              0               0   in           3309508717
# ..           ...            ...             ...  ...                  ...
# 96             0              0               0   in   903230649045204993
# 97             0              0               1   in  1265762823679819776
# 98             0              0               1   in  1265762823679819776
# 99             0              0               2   in   783859591121555456
# 100            0              0               0   in            255866913
#
#      conversation_id_str         username  \
# 0    1757207383942775238     WirawanDavit
# 1    1757207335699931148    Endahrachma03
# 2    1757207136856371480  kanwilbpnsultra
# 3    1757207045554700466         jpieterz
# 4    1757206961714847749        deoagus39
# ..                   ...              ...
# 96   1757167658611650942        Korericom
# 97   1757167541380849746  FachrulAdityaE1
# 98   1757167216523637094  FachrulAdityaE1
# 99   1757166698787229735         XBorn_ID
# 100  1757166253121110485     hariankompas
#
#                                              tweet_url
# 0    https://twitter.com/WirawanDavit/status/175720...
# 1    https://twitter.com/Endahrachma03/status/17572...
# 2    https://twitter.com/kanwilbpnsultra/status/175...
# 3    https://twitter.com/jpieterz/status/1757207045...
# 4    https://twitter.com/deoagus39/status/175720696...
# ..                                                 ...
# 96   https://twitter.com/Korericom/status/175716765...
# 97   https://twitter.com/FachrulAdityaE1/status/175...
# 98   https://twitter.com/FachrulAdityaE1/status/175...
# 99   https://twitter.com/XBorn_ID/status/1757166698...
# 100  https://twitter.com/hariankompas/status/175716...
#
# [101 rows x 12 columns]

# %%
# Menentukan jalur ke file CSV 
file_path = f"tweets-data/{filename}"

# Baca file csv
tweets_df = pd.read_csv(file_path, delimiter=";")

# Buat nama kolom baru untuk mengganti nama kolom
new_columns = {
    'conversation_id_str': 'Conv.ID',
    'tweet_url': 'URL',
    'created_at': 'Date',
    'full_text': 'Tweet',
    'id_str': 'ID',
    'reply_count': 'Replies',
    'retweet_count': 'Retweeted Tweet',
    'favorite_count': 'Likes',
    'lang': 'Language',
    'user_id_str': 'User ID',
    'username': 'Username'
}

# Ganti nama kolom
tweets_df = tweets_df.rename(columns=new_columns)

# Hapus kolom yang tidak diperlukan
tweets_df = tweets_df.drop(columns=['Conv.ID', 'Retweeted Tweet', 'URL', 'ID', 'Replies', 'Likes', 'Language', 'User ID'])

# Atur ulang urutan kolom
tweets_df = tweets_df[['Date', 'Username', 'Tweet']]

# Konversi format tanggal
tweets_df['Date'] = tweets_df['Date'].apply(lambda x: datetime.strptime(x, "%a %b %d %H:%M:%S +0000 %Y").strftime("%Y-%m-%d %H:%M:%S+00:00"))

# Tampilkan DataFrame
display(tweets_df)

# Simpan DataFrame yang telah diubah ke dalam file CSV di folder tweets-data-ready
output_path = f"../../database/crawling/{filename}"  # Perhatikan perubahan path
tweets_df.to_csv(output_path, index=False)
# Out:
#                           Date         Username  \
# 0    2024-02-13 00:57:42+00:00     WirawanDavit
# 1    2024-02-13 00:57:30+00:00    Endahrachma03
# 2    2024-02-13 00:56:44+00:00  kanwilbpnsultra
# 3    2024-02-13 00:56:21+00:00         jpieterz
# 4    2024-02-13 00:56:01+00:00        deoagus39
# ..                         ...              ...
# 96   2024-02-12 22:19:51+00:00        Korericom
# 97   2024-02-12 22:19:23+00:00  FachrulAdityaE1
# 98   2024-02-12 22:18:05+00:00  FachrulAdityaE1
# 99   2024-02-12 22:16:02+00:00         XBorn_ID
# 100  2024-02-12 22:14:15+00:00     hariankompas
#
#                                                  Tweet
# 0    Telah beredar buletin digital yang memuat tuli...
# 1    Biasanya berangkat kerja selalu kena macet, Al...
# 2    Hindari Golput agar aspirasi dapat terwujud 😎 ...
# 3             Exit poll abal2. Lawak lawak #Pemilu2024
# 4    Pemasangan bilik suara #Pemilu2024 #PemiluDama...
# ..                                                 ...
# 96   https://t.co/uNnYxyEv4s  Dirut PLN Pimpin Lang...
# 97   ZECKY ALATAS CALON ANGGOTA DPD RI 2024-2029 DA...
# 98   ZECKY ALATAS CALON ANGGOTA DPD RI 2024-2029 DA...
# 99   Ini Film Dirty Vote" (Full Movie) di YouTube, ...
# 100  Pemilih Ekspresif dan Demokrasi #Pemilu2024 #A...
#
# [101 rows x 3 columns]
